# %%
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.cross_validation import train_test_split
from sklearn.neighbors import KNeighborsClassifier
import numpy as np
from sklearn.svm import SVC
# Out:
# C:\Miniconda3\envs\ADS\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
from sklearn.cross_validation import train_test_split

# %% [markdown]
# # Traitement par KNN

# %%
def KNN(size,X_train,X_test,y_train,y_test):

    X_train,X_test_notused,y_train,y_test_notused=train_test_split(X_train,y_train,test_size=i/1000,random_state=11)
    


    knn = KNeighborsClassifier(n_neighbors=10)
    digit_knn=knn.fit(X_train, y_train)
    s2=1-digit_knn.score(X_train, y_train)
    s= 1-digit_knn.score(X_test,y_test)
    return s,s2

# %%
def SVM(size,X_train,X_test,y_train,y_test):

    X_train,X_test_notused,y_train,y_test_notused=train_test_split(X_train,y_train,test_size=i/1000,random_state=11)
    


    clf = SVC(probability=True, C=100.0, gamma=0.1, kernel='linear')
    clf.fit(X_train, y_train)

    s2=1-clf.score(X_train, y_train)
    s= 1-clf.score(X_test,y_test)
    return s,s2

# %%
v_tailles=np.arange(20,1000,10)
sortieTestKNN=np.arange(float(len(v_tailles)))
sortieTrainKNN=np.arange(float(len(v_tailles)))
sortieTestSVM=np.arange(float(len(v_tailles)))
sortieTrainSVM=np.arange(float(len(v_tailles)))

#dataset

digits = datasets.load_digits()
X=digits.data[0:1000]
y=digits.target[0:1000]
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.33,random_state=11)
        
for i in range(len(v_tailles)):
    #select V_tailles(i) random trainset from x_train

    [s,s2]=KNN(v_tailles[i],X_train,X_test,y_train,y_test)
    sortieTestKNN[i]=s
    sortieTrainKNN[i]=s2
    
    [s,s2]=SVM(v_tailles[i],X_train,X_test,y_train,y_test)
    sortieTestSVM[i]=s
    sortieTrainSVM[i]=s2

# %%
print(sortieTestKNN)
print(sortieTrainKNN)
# Out:
# [0.02424242 0.02424242 0.02424242 0.02424242 0.02424242 0.02424242
#  0.02424242 0.02424242 0.02424242 0.02424242 0.02424242 0.02424242
#  0.02424242 0.02424242 0.02424242 0.02424242 0.02424242 0.02424242
#  0.02424242 0.02424242 0.02727273 0.02727273 0.02727273 0.02727273
#  0.02727273 0.02727273 0.02727273 0.02727273 0.02727273 0.02727273
#  0.02727273 0.02727273 0.02727273 0.02727273 0.02727273 0.02727273
#  0.02727273 0.02727273 0.02727273 0.02727273 0.02727273 0.02727273
#  0.02727273 0.02727273 0.02727273 0.02727273 0.02727273 0.02727273
#  0.02727273 0.02727273 0.03030303 0.02727273 0.02727273 0.03030303
#  0.03030303 0.03030303 0.02727273 0.03030303 0.03030303 0.03030303
#  0.03030303 0.03030303 0.03030303 0.03030303 0.03030303 0.02727273
#  0.02727273 0.02727273 0.02727273 0.03030303 0.03030303 0.03333333
#  0.03333333 0.03333333 0.03333333 0.03333333 0.03333333 0.03333333
#  0.